# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('train_data.csv', index_col = 0)
target = pd.read_csv('train_target.csv', index_col = 0)

# %%
train.head()
# Out:
#           id        date  bedrooms_number  batchrooms_number  \
# index
# 0      16530  2014-05-02                2               2.00
# 1       3651  2014-05-02                3               1.75
# 2      13568  2014-05-02                3               1.75
# 3      20352  2014-05-02                4               2.00
# 4      10524  2014-05-02                4               1.75
#
#        square_footage_home  square_footage_lot  floors_number  has_waterfront  \
# index
# 0                     1350                2560            1.0               0
# 1                     1800               23103            1.0               0
# 2                     2240               10578            2.0               0
# 3                     1820                5000            1.5               0
# 4                     1560                8700            1.0               0
#
#        has_been_viewed  condition_quality  housing_unity_grade  \
# index
# ...

# %%
target.head()
# Out:
#        price
# index
# 0      340.0
# 1      289.0
# 2      755.0
# 3      655.0
# 4      387.5

# %%
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.25, random_state=42)

# %%
X_train.head()
# Out:
#           id        date  bedrooms_number  batchrooms_number  \
# index
# 14583    452  2014-12-31                4               2.50
# 7517    3407  2014-08-21                4               2.75
# 13838   5033  2014-12-11                3               2.50
# 15539  16862  2015-01-29                4               1.00
# 15563  15241  2015-01-29                5               2.50
#
#        square_footage_home  square_footage_lot  floors_number  has_waterfront  \
# index
# 14583                 2280               27441            2.0               0
# 7517                  2790                8092            2.0               0
# 13838                 2000                1950            3.0               0
# 15539                 1010                7515            1.0               0
# 15563                 3320                7266            2.0               0
#
#        has_been_viewed  condition_quality  housing_unity_grade  \
# index
# ...

# %%
X_train.to_csv('train.csv', index=False)
y_train.to_csv('target.csv', index=False)
X_test.to_csv('test.csv', index=False)
y_test.to_csv('test_answer.csv', index=False)

# %%
train = pd.read_csv('home/danil/ML/Server/Flask/test/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-166c5fd738c9> in <module>
# ----> 1 train = pd.read_csv('home/danil/ML/Server/Flask/test/train.csv')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
train
# Out:
#           id        date  bedrooms_number  batchrooms_number  \
# index
# 0      16530  2014-05-02                2               2.00
# 1       3651  2014-05-02                3               1.75
# 2      13568  2014-05-02                3               1.75
# 3      20352  2014-05-02                4               2.00
# 4      10524  2014-05-02                4               1.75
# ...      ...         ...              ...                ...
# 17275   7718  2015-03-10                4               2.50
# 17276   4556  2015-03-10                3               2.50
# 17277  11634  2015-03-10                3               1.00
# 17278  16309  2015-03-10                2               1.00
# 17279  16613  2015-03-10                3               2.25
#
#        square_footage_home  square_footage_lot  floors_number  has_waterfront  \
# index
# 0                     1350                2560            1.0               0
# ...
